# %% [markdown]
# # Run GGM Batch for Denmark

# %%
# !python ggm_batch.py --ticker_file nordic_tickers_denmark.txt --country denmark --ggm_args --market_ticker ^OMXC25 --method regression --multi_stage

# %% [markdown]
# # Run GGM Batch for Sweden

# %%
# !python ggm_batch.py --ticker_file nordic_tickers_sweden.txt --country sweden --ggm_args --market_ticker ^OMXS30 --method regression --multi_stage
# Out:
# Running GGM for ALFA.ST...
#
# Gordon Growth Model Value for ALFA.ST: 181.79
#   D1 (next dividend): 9.48
#   Required Return: 7.91%
#   Growth Rate: 11.56%
#   Last Dividend: 8.50
#   Method: multi-stage, Periods: 5
#   Current Price: 398.50
#   Potential Upside: -54.38%
#   Return on Equity (ROE): 18.74%
#   Cost of Equity (Required Return): 7.91%
#   Debt/Equity Ratio: 29.47
#   Interest Coverage Ratio: N/A
#   WARNING: Debt/Equity ratio is high. Financial risk may be elevated.
#
# Running GGM for ASSA-B.ST...
#
# Gordon Growth Model Value for ASSA-B.ST: 145.28
#   D1 (next dividend): 6.57
#   Required Return: 7.12%
#   Growth Rate: 11.40%
#   Last Dividend: 5.90
#   Method: multi-stage, Periods: 5
#   Current Price: 295.80
#   Potential Upside: -50.88%
#   Return on Equity (ROE): 14.52%
#   Cost of Equity (Required Return): 7.12%
#   Debt/Equity Ratio: 74.28
#   Interest Coverage Ratio: N/A
#   WARNING: Debt/Equity ratio is high. Financial risk may be elevated.
#
# ...

# %%
# !python gordon_growth.py --ticker SWED-A.ST --market_ticker ^OMXS30 --method regression --multi_stage --high_growth_rate 0.05
# Out:
# Gordon Growth Model Value for SWED-A.ST: 585.30
#   D1 (next dividend): 22.79
#   Required Return: 6.06%
#   Growth Rate: 5.00%
#   Last Dividend: 21.70
#   Method: multi-stage, Periods: 5
#   Current Price: 249.40
#   Potential Upside: 134.68%
# Return on Equity (ROE): 17.64%
# Cost of Equity (Required Return): 6.06%
# Debt/Equity Ratio: N/A
# Interest Coverage Ratio: N/A
# Debt/Equity and Interest Coverage data not available.

# %% [markdown]
# # Run GGM Batch for Norway

# %%
# !python ggm_batch.py --ticker_file nordic_tickers_norway.txt --country norway --ggm_args --market_ticker ^OBX --method regression --multi_stage
# Out:
# Running GGM for BAKKA.OL...
#
# Gordon Growth Model Value for BAKKA.OL: 592.87
#   D1 (next dividend): 17.52
#   Required Return: 6.28%
#   Growth Rate: 30.97%
#   Last Dividend: 13.37
#   Method: multi-stage, Periods: 5
#   Current Price: 453.00
#   Potential Upside: 30.88%
# Return on Equity (ROE): 2.12%
# Cost of Equity (Required Return): 6.28%
# Debt/Equity Ratio: 36.33
# Interest Coverage Ratio: N/A
# WARNING: ROE is less than the required return (cost of equity). Long-term growth may be questionable.
# WARNING: Debt/Equity ratio is high. Financial risk may be elevated.
#
# Running GGM for DNB.OL...
#
# Gordon Growth Model Value for DNB.OL: 490.88
#   D1 (next dividend): 17.47
#   Required Return: 5.67%
#   Growth Rate: 4.28%
#   Last Dividend: 16.75
#   Method: multi-stage, Periods: 5
#   Current Price: 274.20
#   Potential Upside: 79.02%
# Return on Equity (ROE): 16.15%
# Cost of Equity (Required Return): 5.67%
# Debt/Equity Ratio: N/A
# Interest Coverage Ratio: N/A
# ...

# %% [markdown]
# # Run GGM Batch for Finland

# %%
# !python ggm_batch.py --ticker_file nordic_tickers_finland.txt --country finland --ggm_args --market_ticker ^OMXH25 --method regression --multi_stage
