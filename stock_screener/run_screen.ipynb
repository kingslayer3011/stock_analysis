# %%
from functions import *
#run_extraction()

# %%
screen1 = {
    #"current_ratio": { "min": 1 },
    "PB Ratio": { "min": 0,  "max": 20 },
    "PE Ratio": { "min": 0,  "max": 20 },
    "cagr_eps": { "min": 0,  "max": 999 },
    "p_to_graham": { "min": 0,  "max": 1 },
    "exclude_sectors": ["Financials"],
  }

# Save stats to JSON
with open("screen1.json", "w") as f:
    json.dump(screen1, f, indent=2)

run_screen("screen1.json")
# Out:
# {'PB Ratio': {'min': 0, 'max': 20}, 'PE Ratio': {'min': 0, 'max': 20}, 'cagr_eps': {'min': 0, 'max': 999}, 'p_to_graham': {'min': 0, 'max': 1}, 'exclude_sectors': ['Financials']}
#       ticker     company_name  PB Ratio   PE Ratio  cagr_eps  p_to_graham
# 0  CARL-B.CO  Carlsberg A/S B  1.448529  11.947345  0.093638     0.877017
# 1     ISS.CO          ISS A/S  1.016081  19.025747  0.309000     0.926923
# 2     ORK.OL        Orkla ASA  1.618709  10.227759  0.217163     0.857795
# 3  FORTUM.HE       Fortum Oyj  1.103053  13.594916  0.090596     0.816385
# 4   HUH1V.HE    Huhtamäki Oyj  1.043907  15.674710  0.001186     0.852785
# 5  KEMIRA.HE       Kemira Oyj  1.173156  12.754740  0.197888     0.815497
# 6     KCR.HE         Kone Oyj  1.480775  14.900466  0.270632     0.990269
# Filtered results saved to: screen1_results.csv
